# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# # Títulos
# ## Subtítulos
# ##### skfasdng
# *Esto es cursiva* **esto es negrita**
# [enlace a google ](https://www.google.com/?hl=es)
#
# ![Texto alternativo](./static/img1.jpeg)
